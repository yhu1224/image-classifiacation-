# %%
# %matplotlib inline
#the above line enables displaying images withinin the notebook rather than a separate window
from scipy.misc import imread, imresize #reading and resizing images
import matplotlib.pyplot as plt #displaying images
import dask.bag as db  #For easy parallelization of applying a function on a list
import numpy as np

# %%
DATA_PATH = r"N:\DATA\distracted_driver_classification"

# %%
#use imread to read image
sample_image = imread(DATA_PATH + r'\imgs\train\c0\img_100026.jpg')

# %%
sample_image.shape
# Out:
# (480, 640, 3)

# %%
plt.imshow(sample_image)

# %% [markdown]
# # Red/Green/Blue Components

# %% [markdown]
# ### Red

# %%
#why do this step fill 0 to the sample image
red_component = np.zeros_like(sample_image)
#
red_component[:,:,0] = sample_image[:,:,0]
plt.imshow(red_component)

# %%
sample_image.shape
# Out:
# (480, 640, 3)

# %% [markdown]
# ### Green

# %%
green_component = np.zeros_like(sample_image)
green_component[:,:,1] = sample_image[:,:,1]
plt.imshow(green_component)

# %% [markdown]
# ### Blue

# %%
blue_component = np.zeros_like(sample_image)
blue_component[:,:,2] = sample_image[:,:,2]
plt.imshow(blue_component)

# %%
#????????????????
sample_image[:,:,0]
# Out:
# array([[ 34,  29,  30, ..., 136, 191, 218],
#        [ 34,  30,  29, ..., 180, 204, 205],
#        [ 30,  31,  36, ..., 199, 209, 209],
#        ...,
#        [ 34,  31,  29, ...,  12,  12,  10],
#        [ 65,  56,  48, ...,  12,  12,   9],
#        [111,  99,  83, ...,  12,  12,   8]], dtype=uint8)

# %%
sample_image[:,:,1]
# Out:
# array([[ 38,  32,  32, ..., 192, 240, 255],
#        [ 40,  36,  34, ..., 236, 254, 251],
#        [ 38,  39,  43, ..., 255, 255, 255],
#        ...,
#        [ 58,  53,  50, ...,  11,  11,   9],
#        [ 89,  80,  71, ...,  11,  11,   8],
#        [135, 123, 106, ...,  11,  11,   7]], dtype=uint8)

# %% [markdown]
# ### Grayscale Representation

# %%
# take the mean of each row
sample_grayscale = sample_image.mean(axis=2)
sample_grayscale.shape
# Out:
# (480, 640)

# %%
plt.imshow(sample_grayscale, cmap = 'gray')

# %% [markdown]
# ## Cropping and downsampling

# %%
sample_grayscale.shape
# Out:
# (480, 640)

# %%
#take the x axis from 40 to 400, y axis from 120 to 640; change it into 64x64
sample_downsampled = imresize(sample_grayscale[40:400, 120:640], (64, 64))

# %%
plt.imshow(sample_downsampled, cmap='gray')
